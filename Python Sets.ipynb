# %%
set1={1,2,3,4}

set1

set2={1,2,'hello',(1,2,3)}

set3={1,2,'hello',[19,87,62]}

set3=set([1,2,3])
set3

set3.add(4)

set3

set3.update([2,6,7,8,9])

set3

set4={}

set4.add(5)
set4

set3.discard(6)

set3

set3.remove(8)

set3

set3.update(['zd','tm'])

set3

set3.pop()
set3

set3.clear()

set3

A={1,2,3,4,5}
B={4,5,6,7,8}

A|B

A.union(B)

B.union(A)

A&B

A.intersection(B)

B.intersection(A)
